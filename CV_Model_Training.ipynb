# %%
# !pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 8.5 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 70.5 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 14.9 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.8 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 80.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 12.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 12.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 4.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.2 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.27.1 xxhash-3.2.0 yarl-1.8.2

# %%
from datasets import load_dataset

ds = load_dataset('PriyamSheta/EmotionClass')
ds
# Out:
# Downloading and preparing dataset imagefolder/PriyamSheta--EmotionClass to /root/.cache/huggingface/datasets/PriyamSheta___imagefolder/PriyamSheta--EmotionClass-bd876b37a60a1536/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files:   0%|          | 0/200 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.39k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.69k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.85k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.79k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.85k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.71k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.08k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.39k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.99k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.68k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.57k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.80k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.57k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.21k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.94k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.99k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.48k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.60k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.47k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.94k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.16k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.02k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.91k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.99k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.33k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.74k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.52k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.92k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.64k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.09k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.27k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.87k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.78k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.84k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.73k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.65k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.94k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.30k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.69k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.46k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.84k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.74k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.89k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.02k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.91k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.54k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.38k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.84k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.47k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.21k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.99k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.26k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.58k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.90k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.76k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.22k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.91k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.50k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.76k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.06k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.85k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.33k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.50k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.17k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.78k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.45k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.02k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.90k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.80k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.71k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.93k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.93k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.52k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.21k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.13k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.21k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.58k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.87k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.99k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.23k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.82k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.00k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.72k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.43k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.86k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.55k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/24 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/7.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.82k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.54k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.89k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.79k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.82k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.60k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.64k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.61k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/26 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.69k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.02k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.83k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.65k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.70k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.55k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.33k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.62k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /root/.cache/huggingface/datasets/PriyamSheta___imagefolder/PriyamSheta--EmotionClass-bd876b37a60a1536/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 200
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 24
#     })
#     validation: Dataset({
#         features: ['image', 'label'],
#         num_rows: 26
#     })
# })

# %%
# !pip install -q wandb
import wandb
# !wandb login --relogin "360174bce7646ca597114af508269231aaadba07"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.5 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from transformers import ViTFeatureExtractor

model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
import os
def transform(example_batch):
    # Take a list of PIL images and turn them to pixel values
    inputs = feature_extractor([x for x in example_batch['image']], return_tensors='pt')

    # Don't forget to include the labels!
    inputs['label'] = example_batch['label']
    return inputs

prepared_ds = ds.with_transform(transform)
os.environ["WANDB_PROJECT"]="train"

# save your trained model checkpoint to wandb
os.environ["WANDB_LOG_MODEL"]="true"

# %%
import torch
import numpy as np
from datasets import load_metric
from transformers import TrainingArguments
from transformers import Trainer

metric = load_metric("accuracy")

def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)

def collate_fn(batch):
    return {
        'pixel_values': torch.stack([x['pixel_values'] for x in batch]),
        'labels': torch.tensor([x['label'] for x in batch])
    }

from transformers import ViTForImageClassification

labels = ds['train'].features['label'].names

model = ViTForImageClassification.from_pretrained(
    model_name_or_path,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)}
)

training_args = TrainingArguments(
  output_dir="./vit-base-beans",
  per_device_train_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=4,
  report_to="wandb",
  fp16=False,
  save_steps=40,
  eval_steps=40,
  logging_steps=10,
  learning_rate=2e-4,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  load_best_model_at_end=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    train_dataset=prepared_ds["train"],
    eval_dataset=prepared_ds["validation"],
    tokenizer=feature_extractor,
)

train_results = trainer.train()
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 1:11:38, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>40</td>
#       <td>0.217700</td>
#       <td>0.571349</td>
#       <td>0.692308</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.058000</td>
#       <td>0.459362</td>
#       <td>0.807692</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** train metrics *****
#   epoch                    =        4.0
#   total_flos               = 57736031GF
#   train_loss               =     0.2271
#   train_runtime            = 1:12:17.70
#   train_samples_per_second =      0.184
#   train_steps_per_second   =      0.023

# %%
print("Hi")
# Out:
# Hi

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import HfApi

api = HfApi()

api.upload_folder(
    folder_path="/content/vit-base-beans/checkpoint-80",
    path_in_repo = ".",
    repo_id="PriyamSheta/EmotionClassModel",
    repo_type="model",
    create_pr=1
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# optimizer.pt:   0%|          | 0.00/687M [00:00<?, ?B/s]
# rng_state.pth:   0%|          | 0.00/13.6k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/3.52k [00:00<?, ?B/s]
# scheduler.pt:   0%|          | 0.00/627 [00:00<?, ?B/s]
# 'https://huggingface.co/PriyamSheta/EmotionClassModel/tree/refs%2Fpr%2F1/.'
